# %%
# %run initiate.ipynb

# %%
from astroquery.utils.tap.core import TapPlus

simbad = TapPlus(url='https://simbad.u-strasbg.fr/simbad/sim-tap/')
request = simbad.launch_job_async("SELECT ra, dec FROM basic WHERE otype='YSO'", verbose=True)
ap_table = Table(request.get_results())
result = ap_table.to_pandas()

result.to_csv('../Data/all_yso.csv', index=False)
# Out:
# Launched query: 'SELECT ra, dec FROM basic WHERE otype='YSO''
# ------>https
# host = simbad.u-strasbg.fr:443
# context = /simbad/sim-tap//async
# Content-type = application/x-www-form-urlencoded
# 303 303
# [('Date', 'Fri, 13 Jun 2025 05:33:43 GMT'), ('Server', 'Apache'), ('Set-Cookie', 'JSESSIONID=404FBD5F1F047C8748C14BF82AEB2F1C.new; Path=/simbad; Secure; HttpOnly'), ('Location', 'https://simbad.u-strasbg.fr/simbad/sim-tap/async/1749792823535'), ('Access-Control-Allow-Origin', '*'), ('Transfer-Encoding', 'chunked'), ('Content-Type', 'application/x-www-form-urlencoded;charset=UTF-8')]
# job 1749792823535, at: https://simbad.u-strasbg.fr/simbad/sim-tap/async/1749792823535
# Retrieving async. results...
# INFO: Query finished. [astroquery.utils.tap.core]

# %%
url_api = "https://irsa.ipac.caltech.edu/applications/finderchart/servlet/api"
sources= []
yso_radec = pd.read_csv('../Data/all_yso.csv')

for _, row in yso_radec.iterrows():
    sources.append({'ra': row['ra'], 'dec': row['dec']})

surveys = "WISE,2MASS,SEIP"

base_output = '../Imported_FITS'

output_folders = {
    'WISE1': os.path.join(base_output, 'WISE1'),
    'WISE2': os.path.join(base_output, 'WISE2'),
    'WISE3': os.path.join(base_output, 'WISE3'),
    'WISE4': os.path.join(base_output, 'WISE4'),
    
    '2MASS_h': os.path.join(base_output, '2MASS_h'),
    '2MASS_j': os.path.join(base_output, '2MASS_j'),
    '2MASS_k': os.path.join(base_output, '2MASS_k'),

    'IRAC_1': os.path.join(base_output, 'IRAC_1'),
    'IRAC_2': os.path.join(base_output, 'IRAC_2'),
    'IRAC_3': os.path.join(base_output, 'IRAC_3'),
    'IRAC_4': os.path.join(base_output, 'IRAC_4'),
    'MIPS': os.path.join(base_output, 'MIPS')
}

for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

counter = 0

for source in sources[50:200]:
    counter = counter + 1
    params= {
        'mode': 'getImage',
        'RA': f"{source['ra']}",
        'DEC': f"{source['dec']}",
        'reproject': True,
        'survey': surveys,
        'subsetsize': .25,
    }
    
    response = requests.get(url_api, params=params)

    temp_folder = os.path.join(base_output, f"temp_{source['ra']}_{source['dec']}")
    os.makedirs(temp_folder, exist_ok=True)

    with zipfile.ZipFile(io.BytesIO(response.content)) as zip_data:
        zip_data.extractall(temp_folder)

    for fname in os.listdir(temp_folder):
        # Check which survey this file belongs to by looking for survey name in filename
        fname_upper = fname.upper()
        dest_folder = None
        
        if 'WISE' in fname_upper:
            if 'W1' in fname_upper or 'WISE_1' in fname_upper:
                dest_folder = output_folders['WISE1']
            elif 'WISE_2' in fname_upper:
                dest_folder = output_folders['WISE2']
            elif 'WISE_3' in fname_upper:
                dest_folder = output_folders['WISE3']
            elif 'WISE_4' in fname_upper:
                dest_folder = output_folders['WISE4']
        
        elif 'SPITZER' in fname_upper:
            if '_SEIPIRAC1' in fname_upper:
                dest_folder = output_folders['IRAC_1']
            elif '_SEIPIRAC2' in fname_upper:
                dest_folder = output_folders['IRAC_2']
            elif '_SEIPIRAC3' in fname_upper:
                dest_folder = output_folders['IRAC_3']
            elif '_SEIPIRAC4' in fname_upper:
                dest_folder = output_folders['IRAC_4']
            elif '_SEIPMIPS' in fname_upper:
                dest_folder = output_folders['MIPS']

        elif '2MASS' in fname_upper or '2 MASS' in fname_upper:
            if '_H' in fname_upper:
                dest_folder = output_folders['2MASS_h']
            elif '_J' in fname_upper:
                dest_folder = output_folders['2MASS_j']
            elif '_K' in fname_upper:
                dest_folder = output_folders['2MASS_k']
        
        if dest_folder:
            src_path = os.path.join(temp_folder, fname)
            dst_path = os.path.join(dest_folder, f"{source['ra']}_{source['dec']}_{fname}")
            shutil.move(src_path, dst_path)
        else:
            print(f"WARNING: File {fname} does not match any known survey, skipping.")
    # Remove temp folder once done
    shutil.rmtree(temp_folder)
    print(f"Processed source RA={source['ra']}, DEC={source['dec']}" + ' #' + str(counter))
# Out:
# Processed source RA=313.97682317925, DEC=43.82393842126999 #1
# Processed source RA=287.944693, DEC=9.964548 #2
# Processed source RA=314.24363300453, DEC=43.848183670930005 #3
# Processed source RA=314.37987818983, DEC=44.04376485447 #4
# Processed source RA=287.940818, DEC=9.963964 #5
# Processed source RA=92.064903, DEC=20.52779 #6
# Processed source RA=315.41472545517, DEC=43.88610172993 #7
# Processed source RA=92.102402, DEC=20.614771 #8
# Processed source RA=92.114642, DEC=20.629972 #9
# Processed source RA=92.114722, DEC=20.628773 #10
# Processed source RA=315.11230268084, DEC=44.11977298752 #11
# Processed source RA=92.116405, DEC=20.63105 #12
# Processed source RA=92.12217900000002, DEC=20.638063 #13
# Processed source RA=92.130408, DEC=20.447161 #14
# Processed source RA=314.57646971084995, DEC=43.87993732433 #15
# Processed source RA=92.138617, DEC=20.677395 #16
# Processed source RA=308.115018, DEC=40.320709 #17
# Processed source RA=308.0795416666667, DEC=40.33652777777778 #18
# Processed source RA=308.097945, DEC=40.343094 #19
# Processed source RA=308.11346000000003, DEC=40.323082 #20
# Processed source RA=308.087829, DEC=40.31336600000001 #21
# Processed source RA=308.07473200000004, DEC=40.33290100000001 #22
# Processed source RA=314.69056104236, DEC=44.2021228347 #23
# Processed source RA=314.68304261823, DEC=44.23128130959 #24
# Processed source RA=308.122544, DEC=40.321449 #25
# Processed source RA=308.078118, DEC=40.334232 #26
# Processed source RA=308.10842, DEC=40.31786699999999 #27
# Processed source RA=308.077481, DEC=40.33665700000001 #28
# Processed source RA=314.80591031781, DEC=44.23196673846 #29
# Processed source RA=314.80847841241, DEC=44.26999821091 #30
# Processed source RA=308.092551, DEC=40.332184 #31
# Processed source RA=308.073413, DEC=40.333988000000005 #32
# Processed source RA=308.0841690000001, DEC=40.313592 #33
# Processed source RA=314.39293743506, DEC=44.0940610661 #34
# Processed source RA=92.154102, DEC=20.656109 #35
# Processed source RA=82.32820516496, DEC=-1.31030693008 #36
# Processed source RA=315.11354735206, DEC=44.70708271142 #37
# Processed source RA=92.161095, DEC=20.592916 #38
# Processed source RA=92.161331, DEC=20.620291 #39
# Processed source RA=92.164583, DEC=20.615532 #40
# Processed source RA=92.176252, DEC=20.646841 #41
# Processed source RA=92.183505, DEC=20.653616 #42
# Processed source RA=92.202226, DEC=20.490599 #43
# Processed source RA=92.202782, DEC=20.492102000000003 #44
# Processed source RA=92.206453, DEC=20.492123000000003 #45
# Processed source RA=92.229583, DEC=20.673189 #46
# Processed source RA=92.236343, DEC=20.49217 #47
# Processed source RA=92.261084, DEC=20.457619 #48
# Processed source RA=92.275589, DEC=20.703886 #49
# Processed source RA=92.279164, DEC=20.7013 #50
# Processed source RA=166.76350543965, DEC=-76.1824037936 #51
# Processed source RA=92.345551, DEC=20.707941 #52
# Processed source RA=92.341804, DEC=20.607533 #53
# Processed source RA=92.342335, DEC=20.699347 #54
# Processed source RA=92.35289000000002, DEC=20.702951 #55
# Processed source RA=83.80804329166665, DEC=-5.402616583333334 #56
# Processed source RA=92.367638, DEC=20.743441000000004 #57
# Processed source RA=286.920167, DEC=7.402818 #58
# Processed source RA=92.436516, DEC=20.712893 #59
# Processed source RA=92.422038, DEC=20.592381 #60
# Processed source RA=92.421478, DEC=20.596087 #61
# Processed source RA=92.42931102989, DEC=20.62513732976 #62
# Processed source RA=67.68429166666667, DEC=35.99752777777779 #63
# Processed source RA=313.1389375, DEC=44.528 #64
# Processed source RA=87.774258, DEC=27.538868000000004 #65
# Processed source RA=87.784781, DEC=27.503157 #66
# Processed source RA=93.09991666666666, DEC=17.900277777777777 #67
# Processed source RA=93.10283333333334, DEC=17.98913888888889 #68
# Processed source RA=313.2316270166, DEC=44.24707006411 #69
# Processed source RA=93.105242, DEC=17.922695 #70
# Processed source RA=93.107257, DEC=17.918243 #71
# Processed source RA=87.853801, DEC=27.492769 #72
# Processed source RA=93.106175, DEC=17.932597222222224 #73
# Processed source RA=93.15514, DEC=17.912434 #74
# Processed source RA=93.113875, DEC=17.925083333333333 #75
# Processed source RA=93.12912500000002, DEC=17.91861111111111 #76
# Processed source RA=93.113504, DEC=17.919716 #77
# Processed source RA=93.117275, DEC=17.924589 #78
# Processed source RA=93.113663, DEC=17.989862 #79
# Processed source RA=93.12329166666667, DEC=17.91197222222222 #80
# Processed source RA=93.12854166666668, DEC=17.92313888888889 #81
# Processed source RA=93.13386422551, DEC=17.913485334659995 #82
# Processed source RA=93.22725, DEC=17.92338888888889 #83
# Processed source RA=87.792849, DEC=27.531767 #84
# Processed source RA=93.17170833333336, DEC=17.82547222222222 #85
# Processed source RA=93.15379166666666, DEC=17.941166666666664 #86
# Processed source RA=93.16225, DEC=17.945055555555555 #87
# Processed source RA=93.176613, DEC=17.93026 #88
# Processed source RA=93.19541666666667, DEC=17.973333333333333 #89
# Processed source RA=87.870986, DEC=27.471273 #90
# Processed source RA=93.18120833333332, DEC=17.951333333333334 #91
# Processed source RA=93.185979, DEC=17.951502 #92
# Processed source RA=303.072276, DEC=34.46988699999999 #93
# Processed source RA=93.18279166666667, DEC=17.945222222222224 #94
# Processed source RA=93.205597, DEC=17.912287 #95
# Processed source RA=93.213309, DEC=18.014814 #96
# Processed source RA=93.22258333333332, DEC=17.93927777777777 #97
# Processed source RA=93.21608333333334, DEC=18.01708333333333 #98
# Processed source RA=93.221375, DEC=17.918250000000008 #99
# Processed source RA=93.22233333333332, DEC=18.00763888888889 #100
# Processed source RA=93.22291666666666, DEC=17.93169444444445 #101
# Processed source RA=93.22570833333334, DEC=17.984055555555557 #102
# Processed source RA=93.22159166666664, DEC=17.984961111111115 #103
# Processed source RA=93.225125, DEC=18.003166666666665 #104
# Processed source RA=93.22691666666668, DEC=17.923111111111115 #105
# Processed source RA=93.229988, DEC=17.957363 #106
# Processed source RA=93.23377916666666, DEC=17.981011111111112 #107
# Processed source RA=343.77656141677, DEC=62.46926008168 #108
# Processed source RA=93.236809, DEC=17.975554 #109
# Processed source RA=93.239464, DEC=18.025984 #110
# Processed source RA=93.434007, DEC=17.926208 #111
# Processed source RA=93.26729166666668, DEC=17.849361111111108 #112
# Processed source RA=93.24591666666666, DEC=17.973055555555554 #113
# Processed source RA=93.265936, DEC=17.84746 #114
# Processed source RA=93.26895833333334, DEC=17.837722222222222 #115
# Processed source RA=93.27008333333336, DEC=17.84075 #116
# Processed source RA=93.442281, DEC=17.921543000000003 #117
# Processed source RA=93.249375, DEC=17.990694444444443 #118
# Processed source RA=93.26479572812, DEC=18.03959647972 #119
# Processed source RA=93.254384, DEC=17.964247 #120
# Processed source RA=93.460324, DEC=17.91089 #121
# Processed source RA=93.26775, DEC=17.841166666666663 #122
# Processed source RA=93.27030622374, DEC=17.843459610060002 #123
# Processed source RA=93.26854166666666, DEC=17.840999999999998 #124
# Processed source RA=93.27373592007, DEC=17.83822401443 #125
# Processed source RA=93.271789, DEC=17.847103 #126
# Processed source RA=93.27129166666668, DEC=17.829777777777778 #127
# Processed source RA=93.27408333333334, DEC=17.830111111111105 #128
# Processed source RA=93.273, DEC=17.84316666666666 #129
# Processed source RA=93.27491666666668, DEC=17.82358333333334 #130
# Processed source RA=93.28683333333332, DEC=17.848888888888887 #131
# Processed source RA=93.27529166666667, DEC=17.84358333333334 #132
# Processed source RA=93.279791, DEC=17.804611 #133
# Processed source RA=93.27637500000002, DEC=17.983972222222224 #134
# Processed source RA=93.27895833333334, DEC=17.817916666666665 #135
# Processed source RA=93.280052, DEC=17.983862 #136
# Processed source RA=260.224328, DEC=-35.76104 #137
# Processed source RA=93.287575803273, DEC=17.831268498500698 #138
# Processed source RA=93.28318744837, DEC=18.05855335929 #139
# Processed source RA=93.28975, DEC=17.989416666666667 #140
# Processed source RA=93.466116, DEC=17.904612 #141
# Processed source RA=93.288454, DEC=17.969181 #142
# Processed source RA=93.453212, DEC=17.903121 #143
# Processed source RA=93.298331, DEC=17.819908 #144
# Processed source RA=93.461726, DEC=17.903207 #145
# Processed source RA=93.32345833333332, DEC=17.971249999999998 #146
# Processed source RA=93.33741666666666, DEC=17.94461111111111 #147
# Processed source RA=93.3455859916347, DEC=17.935969473236298 #148
# Processed source RA=93.34916172374, DEC=17.88198664369 #149
# Processed source RA=315.5206192336, DEC=44.9029553086 #150

# %%
url_api = "https://irsa.ipac.caltech.edu/applications/finderchart/servlet/api"
sources= []
fake_data2 = pd.read_csv('../Data/fake_rg.csv')

for _, row in fake_data.iterrows():
    sources.append({'ra': row['ra'], 'dec': row['dec']})

surveys = "WISE,2MASS,SEIP"

base_output = '../Imported_FITS_Fake'

output_folders = {
    'WISE1': os.path.join(base_output, 'WISE1'),
    'WISE2': os.path.join(base_output, 'WISE2'),
    'WISE3': os.path.join(base_output, 'WISE3'),
    'WISE4': os.path.join(base_output, 'WISE4'),
    
    '2MASS_h': os.path.join(base_output, '2MASS_h'),
    '2MASS_j': os.path.join(base_output, '2MASS_j'),
    '2MASS_k': os.path.join(base_output, '2MASS_k'),

    'IRAC_1': os.path.join(base_output, 'IRAC_1'),
    'IRAC_2': os.path.join(base_output, 'IRAC_2'),
    'IRAC_3': os.path.join(base_output, 'IRAC_3'),
    'IRAC_4': os.path.join(base_output, 'IRAC_4'),
    'MIPS': os.path.join(base_output, 'MIPS')
}

for folder in output_folders.values():
    os.makedirs(folder, exist_ok=True)

counter = 0

for source in sources[:50]:
    counter = counter + 1
    params= {
        'mode': 'getImage',
        'RA': f"{source['ra']}",
        'DEC': f"{source['dec']}",
        'reproject': True,
        'survey': surveys,
        'subsetsize': .25,
    }
    
    response = requests.get(url_api, params=params)

    temp_folder = os.path.join(base_output, f"temp_{source['ra']}_{source['dec']}")
    os.makedirs(temp_folder, exist_ok=True)

    with zipfile.ZipFile(io.BytesIO(response.content)) as zip_data:
        zip_data.extractall(temp_folder)

    for fname in os.listdir(temp_folder):
        # Check which survey this file belongs to by looking for survey name in filename
        fname_upper = fname.upper()
        dest_folder = None
        
        if 'WISE' in fname_upper:
            if 'W1' in fname_upper or 'WISE_1' in fname_upper:
                dest_folder = output_folders['WISE1']
            elif 'WISE_2' in fname_upper:
                dest_folder = output_folders['WISE2']
            elif 'WISE_3' in fname_upper:
                dest_folder = output_folders['WISE3']
            elif 'WISE_4' in fname_upper:
                dest_folder = output_folders['WISE4']
        
        elif 'SPITZER' in fname_upper:
            if '_SEIPIRAC1' in fname_upper:
                dest_folder = output_folders['IRAC_1']
            elif '_SEIPIRAC2' in fname_upper:
                dest_folder = output_folders['IRAC_2']
            elif '_SEIPIRAC3' in fname_upper:
                dest_folder = output_folders['IRAC_3']
            elif '_SEIPIRAC4' in fname_upper:
                dest_folder = output_folders['IRAC_4']
            elif '_SEIPMIPS' in fname_upper:
                dest_folder = output_folders['MIPS']

        elif '2MASS' in fname_upper or '2 MASS' in fname_upper:
            if '_H' in fname_upper:
                dest_folder = output_folders['2MASS_h']
            elif '_J' in fname_upper:
                dest_folder = output_folders['2MASS_j']
            elif '_K' in fname_upper:
                dest_folder = output_folders['2MASS_k']
        
        if dest_folder:
            src_path = os.path.join(temp_folder, fname)
            dst_path = os.path.join(dest_folder, f"{source['ra']}_{source['dec']}_{fname}")
            shutil.move(src_path, dst_path)
        else:
            print(f"WARNING: File {fname} does not match any known survey, skipping.")
    # Remove temp folder once done
    shutil.rmtree(temp_folder)
    print(f"Processed source RA={source['ra']}, DEC={source['dec']}" + ' #' + str(counter))

# %%
import matplotlib.pyplot as plt
from astropy.io import fits

hdul = fits.open('../Imported_FITS/WISE2/315.590522916_43.82150167889_fc_315.590523+43.821502_wise_2_reproj.fits')

image_data = hdul[0].data

plt.imshow(image_data, cmap='inferno', origin='lower')
plt.colorbar()
plt.title('FITS Image')
plt.show()
